# %% [markdown]
# ## Домашнее задание

# %% [markdown]
# **Задание 1**. Даны 2 строки: *long_phrase* и *short_phrase*.
# Напишите код, который проверяет действительно ли длинная фраза *long_phrase* длиннее короткой *short_phrase*. И выводит *True* или *False* в зависимости от результата сравнения.

# %%
long_phrase = 'Насколько проще было бы писать программы, если бы не заказчики'
short_phrase = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'

# %%
print(len(long_phrase) > len(short_phrase))
# Out:
# True

# %% [markdown]
# **Задание 2**. Дано значение объема файла в байтах. Напишите перевод этого значения в мегабайты в формате: "*Объем файла равен 213.68Mb*"

# %%
file_size_in_bites = 2204442 #  не совсем поняла условие - или надо через ввод просить?
bites_in_mbs = 1024 ** 2
print(f"Объем файла равен {file_size_in_bites / bites_in_mbs:.2f}Mb")
# Out:
# Объем файла равен 2.10Mb

# %% [markdown]
# **Задание 3**. Разработать приложение для определения знака зодиака по дате рождения. Пример:
#
# Введите месяц: март
#
# Введите число: 6
#
# Вывод:
# Рыбы

# %%
'''
с 21 марта по 20 апреля Овен
с 21 апреля по 20 мая Телец
с 21 мая по 21 июня Близнецы
с 22 июня по 22 июля Рак
с 23 июля по 23 августа Лев
с 24 августа по 23 сентября Дева
с 24 сентября по 23 октября Весы
с 24 октября по 22 ноября Скорпион
с 23 ноября по 21 декабря Стрелец
с 22 декабря по 20 января Козерог
с 21 января по 20 февраля Водолей
с 21 февраля по 20 марта Рыбы
'''

month = input("Введите месяц: ").lower()
day = int(input("Введите число: "))

if month == "январь":
    if day < 21:
        zodiac_sign = "Козерог"
    else:
        zodiac_sign = "Водолей"

elif month == "февраль":
    if day < 21:
        zodiac_sign = "Водолей"
    else:
        zodiac_sign = "Рыбы"

elif month == "март":
    if day < 21:
        zodiac_sign = "Рыбы"
    else:
        zodiac_sign = "Овен"
        
elif month == "апрель":
    if day < 21:
        zodiac_sign = "Овен"
    else:
        zodiac_sign = "Телец"
        
elif month == "май":
    if day < 21:
        zodiac_sign = "Телец"
    else:
        zodiac_sign = "Близнецы"
        
elif month == "июнь":
    if day < 22:
        zodiac_sign = "Близнецы"
    else:
        zodiac_sign = "Рак"
        
elif month == "июль":
    if day < 23:
        zodiac_sign = "Рак"
    else:
        zodiac_sign = "Лев"
        
elif month == "август":
    if day < 24:
        zodiac_sign = "Лев"
    else:
        zodiac_sign = "Дева"
        
elif month == "сентябрь":
    if day < 24:
        zodiac_sign = "Дева"
    else:
        zodiac_sign = "Весы"
        
elif month == "октябрь":
    if day < 24:
        zodiac_sign = "Весы"
    else:
        zodiac_sign = "Скорпион"
        
elif month == "ноябрь":
    if day < 23:
        zodiac_sign = "Скорпион"
    else:
        zodiac_sign = "Стрелец"
        
elif month == "декабрь":
    if day < 22:
        zodiac_sign = "Стрелец"
    else:
        zodiac_sign = "Козерог"

else:
    zodiac_sign = ""  # Jupyter запоминает значения предыдущего вызова ячейки?

        
if zodiac_sign:
    print(zodiac_sign)
else:
    print("Вы ввели неправильный месяц.")
# Out:
# Введите месяц: Октябрь
# Введите число: 8
# Весы

# %% [markdown]
# **Задание 4**. Нужно разработать приложение для финансового планирования.
# Приложение учитывает сколько уходит на ипотеку, "на жизнь" и сколько нужно отложить на пенсию.
# Пользователь вводит:
# - заработанную плату в месяц.
# - сколько процентов от ЗП уходит на ипотеку.
# - сколько процентов от ЗП уходит "на жизнь".
# - сколько раз приходит премия в год.
#
# Остальная часть заработанной платы откладывается на пенсию.
#
# Также пользователю приходит премия в размере зарплаты, от которой половина уходит на отпуск, а вторая половина откладывается.
#
# Программа должна учитывать сколько премий было в год.
#
# Нужно вывести сколько денег тратит пользователь на ипотеку и сколько он накопит за год.
#
# Пример:
#
# Введите заработанную плату в месяц: 100000
#
# Введите сколько процентов уходит на ипотеку: 30
#
# Введите сколько процентов уходит на жизнь: 50
#
# Введите количество премий за год: 2
#
# Вывод:
# На ипотеку было потрачено: 360000 рублей
# Было накоплено: 340000 рублей

# %%
salary = int(input("Введите заработанную плату в месяц: "))
mortgage_share = int(input("Введите сколько процентов уходит на ипотеку: ")) / 100
expenses_share = int(input("Введите сколько процентов уходит на жизнь: ")) / 100
bonuses_number = int(input("Введите количество премий за год: "))

vacation_share_in_bonus = 0.5

savings_share = 1 - mortgage_share - expenses_share

mortgage_payment = salary * mortgage_share * 12
savings = salary * (12 * savings_share + bonuses_number * (1 - vacation_share_in_bonus))

print(f"На ипотеку было потрачено: {mortgage_payment:.0f} рублей. Было накоплено: {savings:.0f} рублей")
# Out:
# Введите заработанную плату в месяц: 100000
# Введите сколько процентов уходит на ипотеку: 30
# Введите сколько процентов уходит на жизнь: 50
# Введите количество премий за год: 2
# На ипотеку было потрачено: 360000 рублей. Было накоплено: 340000 рублей

# %% [markdown]
# ## Задание дополнительное

# %% [markdown]
# **Задание 1** https://ru.wikipedia.org/wiki/Fizz_buzz
# Начинающий произносит число “1”, и каждый следующий игрок прибавляет к предыдущему значению единицу. Когда число делится на три оно заменяется на fizz, если число делится на пять, то произносится buzz. Числа, делящиеся на три и пять одновременно заменяются на fizz buzz. Сделавший ошибку игрок исключается из игры.
#
# Типичная партия в fizz buzz выглядит так:
# 1, 2, Fizz, 4, Buzz, Fizz, 7, 8, Fizz, Buzz, 11, Fizz, 13, 14, Fizz Buzz, 16, 17, Fizz, 19, Buzz, Fizz, 22, 23, Fizz, Buzz, 26, Fizz, 28, 29, Fizz Buzz, 31, 32, Fizz, 34, Buzz, Fizz, …
#
# Напишите код, выводящий на экран первые n элементов этой игры (естественно, корректные).

# %%
stop_number = int(input("Введите число до которого играем: "))
output_str = ""

for n in range(1, stop_number + 1):
    if not n % 3:
        current = "Fizz"
        if not n % 5:
            current += " Buzz"
    elif not n % 5:
        current = "Buzz"
    else:
        current = str(n)
    output_str = output_str + ", " + current if output_str else current

print(output_str)
# Out:
# Введите число до которого играем: 36
# 1, 2, Fizz, 4, Buzz, Fizz, 7, 8, Fizz, Buzz, 11, Fizz, 13, 14, Fizz Buzz, 16, 17, Fizz, 19, Buzz, Fizz, 22, 23, Fizz, Buzz, 26, Fizz, 28, 29, Fizz Buzz, 31, 32, Fizz, 34, Buzz, Fizz

# %% [markdown]
# **Задание 2** Датчик принимает сигнал, состоящий из 0 и 1. Известно, что сигнал имеет периодичность, не превышающей натурального числа n. Напишите код, который вычисляет периодичность сигнала. Считайте, что 3 < n < 1000, а общая длина сигнала значительно превышает n.
#
# Пример сигнала с периодичностью 4 (повторяющийся элемент 1011):
# 1011101110111011101110111011101110111011
#
# Еще одна интерпретация задачи, но без кода: https://tproger.ru/problems/endless-train/

# %%
# 1. Генерация случайной последовательности - подготовка данных

import random

PERIOD = 100 # потом поменять на 1000

n = random.randint(3, PERIOD)
pattern = ""

for i in range(n):
    pattern += str(random.randint(0,1))

sequence = pattern * random.randint(3, 20) # потом поменять на любое большое
print(pattern, n, sequence) # for check

# 2. Решение

for n in range(3, PERIOD + 1):
    pattern = sequence[: n]
    for m in range(1, len(sequence) // n):
        if not sequence[n * m : n * (m + 1)] == pattern:
            break
        
    else:
        print(f"Повторяющийся элемент: {pattern}")
        break
# Out:
# 10010101000000111001010100000011110100010000000011000100111001101 65 ...
# Повторяющийся элемент: 10010101000000111001010100000011110100010000000011000100111001101

# %% [markdown]
# **Задание 3** Дано слово из латинских букв. Напишите скрипт, который выводит на экран букву из середины слова (если число букв нечетное). Если букв четное число, то на экран выводятся две буквы из середины.
#
# Для ‘test’ - 'es’
# Для ‘testing’ - ‘t’

# %%
word = input("Введите слово: ")
middle = len(word) // 2

if not len(word) % 2:
    print(word[middle - 1: middle + 1])
else:
    print(word[middle])
# Out:
# Введите слово: test
# es
